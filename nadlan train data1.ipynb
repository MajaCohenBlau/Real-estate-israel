# %%
import pandas as pd
import numpy as np
import requests
import json
import math
import seaborn as sns
from matplotlib import pyplot as plt
import time
import glob
from pathlib import Path
import re

# %%
df = pd.read_csv(r'C:\Users\majac\Desktop\Projects\Real-estate-israel\DealandGushAtribute.csv')
df_cop1  = df.drop(columns = 'religious or not')
df_cop1
# Out:
#         Unnamed: 0  building year  surface area          description  \
# 0                0         1970.0          82.1           appartment
# 1                1         1970.0         115.0           appartment
# 2                2         1970.0         110.0           appartment
# 3                3         1970.0          76.1           appartment
# 4                4         1990.0         127.8           appartment
# ...            ...            ...           ...                  ...
# 192416      192416         1992.0         210.0  single ground house
# 192417      192417         2000.0         200.0  single ground house
# 192418      192418         1998.0          89.0  single ground house
# 192419      192419         1998.0         101.0  single ground house
# 192420      192420         2000.0         200.0  single ground house
#
#         room number    price  deal_year  gush_number building state  \
# 0               3.0  1690000       2019        29536            old
# ...

# %%
df_cop1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192421 entries, 0 to 192420
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           192421 non-null  int64
#  1   building year        192421 non-null  float64
#  2   surface area         192421 non-null  float64
#  3   description          192421 non-null  object
#  4   room number          192421 non-null  float64
#  5   price                192421 non-null  int64
#  6   deal_year            192421 non-null  int64
#  7   gush_number          192421 non-null  int64
#  8   building state       192421 non-null  object
#  9   area bins            192421 non-null  object
#  10  number of bus stops  163158 non-null  float64
#  11  restaurant_number    185683 non-null  float64
#  12  school_gan           129677 non-null  float64
#  13  education_type       129677 non-null  object
# ...

# %%
df_cop2 = df_cop1.fillna({'number of bus stops':0, 
                          'restaurant_number':0, 
                          'school_gan':0, 
                          'education_type':'not found', 
                          'ethnicity':'not found', 
                          'Locality ID': 'not found',
                          'city_name':'not found'
                         })

df_cop2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192421 entries, 0 to 192420
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           192421 non-null  int64
#  1   building year        192421 non-null  float64
#  2   surface area         192421 non-null  float64
#  3   description          192421 non-null  object
#  4   room number          192421 non-null  float64
#  5   price                192421 non-null  int64
#  6   deal_year            192421 non-null  int64
#  7   gush_number          192421 non-null  int64
#  8   building state       192421 non-null  object
#  9   area bins            192421 non-null  object
#  10  number of bus stops  192421 non-null  float64
#  11  restaurant_number    192421 non-null  float64
#  12  school_gan           192421 non-null  float64
#  13  education_type       192421 non-null  object
# ...

# %%
df_cop2['education_type'].unique()
# Out:
# array(['H', 'A', 'not found', 'M', 'mixed', 'O'], dtype=object)

# %%
df_cop2['ethnicity'].unique()
# Out:
# array(['J', 'A', 'not found', 'O'], dtype=object)

# %%
df_cop3 = df_cop2.drop(columns = ['area bins', 'building state', 'ethnicity', 'Locality ID', 'city_name', 'Unnamed: 0'])
df_cop3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192421 entries, 0 to 192420
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   building year        192421 non-null  float64
#  1   surface area         192421 non-null  float64
#  2   description          192421 non-null  object
#  3   room number          192421 non-null  float64
#  4   price                192421 non-null  int64
#  5   deal_year            192421 non-null  int64
#  6   gush_number          192421 non-null  int64
#  7   number of bus stops  192421 non-null  float64
#  8   restaurant_number    192421 non-null  float64
#  9   school_gan           192421 non-null  float64
#  10  education_type       192421 non-null  object
# dtypes: float64(6), int64(3), object(2)
# memory usage: 16.1+ MB

# %%
dum = pd.get_dummies(df_cop3[['description', 'education_type']], prefix = ['', 'school'], )
df_cop4 = pd.concat([dum, df_cop3], axis=1)
df_cop4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192421 entries, 0 to 192420
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   _appartment           192421 non-null  uint8
#  1   _double ground house  192421 non-null  uint8
#  2   _garden appartment    192421 non-null  uint8
#  3   _roof top appartment  192421 non-null  uint8
#  4   _single ground house  192421 non-null  uint8
#  5   school_A              192421 non-null  uint8
#  6   school_H              192421 non-null  uint8
#  7   school_M              192421 non-null  uint8
#  8   school_O              192421 non-null  uint8
#  9   school_mixed          192421 non-null  uint8
#  10  school_not found      192421 non-null  uint8
#  11  building year         192421 non-null  float64
#  12  surface area          192421 non-null  float64
#  13  description           192421 non-null  object
# ...

# %%
df_cop5 = df_cop4.drop(columns = ['description', 'education_type'])
df_cop5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192421 entries, 0 to 192420
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   _appartment           192421 non-null  uint8
#  1   _double ground house  192421 non-null  uint8
#  2   _garden appartment    192421 non-null  uint8
#  3   _roof top appartment  192421 non-null  uint8
#  4   _single ground house  192421 non-null  uint8
#  5   school_A              192421 non-null  uint8
#  6   school_H              192421 non-null  uint8
#  7   school_M              192421 non-null  uint8
#  8   school_O              192421 non-null  uint8
#  9   school_mixed          192421 non-null  uint8
#  10  school_not found      192421 non-null  uint8
#  11  building year         192421 non-null  float64
#  12  surface area          192421 non-null  float64
#  13  room number           192421 non-null  float64
# ...

# %%
df_cop5.to_csv(r'C:\Users\majac\Desktop\Projects\Real-estate-israel\nadlan_train1.csv')
